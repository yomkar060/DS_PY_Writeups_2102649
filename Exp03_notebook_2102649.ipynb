# %% [markdown]
# <a href="https://colab.research.google.com/github/yomkar060/DS_PY_Writeups_2102649/blob/main/Exp03_notebook_2102649.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Experiment No : 03
#
# ##**Aim :**
# Learn basics of maplotlib library and its use as visualisation tool in data science pipeline and learn about line plots and scatter plots.

# %% [markdown]
# ## **Theory :**
#
# **Matplotlib** is a multi-platform data visualization library built on NumPy arrays, and designed to work with the broader SciPy stack.
#
# It was conceived by John Hunter in 2002, originally as a patch to IPython for enabling interactive MATLAB-style plotting via gnuplot from the IPython command line.
#
# One of Matplotlib’s most important features is its ability to play well with many operating systems and graphics backends.
# Matplotlib supports dozens of backends and output types, which means you can count on it to work regardless of which operating system you are using or which output format you wish.
#
# This cross-platform, everything-to-everyone approach has been one of the great strengths of Matplotlib. It has led to a large user base, which in turn has led to an active developer base and Matplotlib’s powerful tools and ubiquity within the scientific Python world.
#
# In recent years, however, the interface and style of Matplotlib have begun to show their age. Newer tools like ggplot and ggvis in the R language, along with web visualization toolkits based on D3js and HTML5 canvas, often make Matplotlib feel clunky and old-fashioned.

# %% [markdown]
# ## Performance :
#
# [Students need to execute eaxh and every cell in this section and note the output of the same. Once done they have to answer Questions mentioned in review section]

# %%
import matplotlib as mpl
import matplotlib.pyplot as plt
mpl.__version__
# Out:
# '3.5.3'

# %%
#setting ploting style
plt.style.use('classic')

# %%
# %matplotlib inline
import numpy as np
x = np.linspace(0, 10, 1000)

fig = plt.figure()
plt.plot(x, np.sin(x))
plt.plot(x, np.cos(x));

# %% [markdown]
# ### Saving Figures to File
#
# One nice feature of Matplotlib is the ability to save figures in a wide variety of formats.
# Saving a figure can be done using the ``savefig()`` command.
# For example, to save the previous figure as a PNG file, you can run this:

# %%
#Save above plot with file named my_figure.png in Current Working Directory
fig.savefig('my_figure.png')

# %%
# Cross check the folder content
# !ls -lh my_figure.png
# Out:
# -rw-r--r-- 1 root root 31K Feb 25 11:12 my_figure.png

# %%
# use Image package in python to check contents of png file in cwd
from IPython.display import Image
Image('my_figure.png')

# %%
#checking supported file types by matplotlib
fig.canvas.get_supported_filetypes()
# Out:
# {'eps': 'Encapsulated Postscript',
#  'jpg': 'Joint Photographic Experts Group',
#  'jpeg': 'Joint Photographic Experts Group',
#  'pdf': 'Portable Document Format',
#  'pgf': 'PGF code for LaTeX',
#  'png': 'Portable Network Graphics',
#  'ps': 'Postscript',
#  'raw': 'Raw RGBA bitmap',
#  'rgba': 'Raw RGBA bitmap',
#  'svg': 'Scalable Vector Graphics',
#  'svgz': 'Scalable Vector Graphics',
#  'tif': 'Tagged Image File Format',
#  'tiff': 'Tagged Image File Format'}

# %% [markdown]
# ### Matplotlib API Interfaces
#
# A potentially confusing feature of Matplotlib is its dual interfaces: a convenient MATLAB-style state-based interface, and a more powerful object-oriented interface. This section we will review them breifly.
#
# #### MATLAB-style Interface
#
# Matplotlib was originally written as a Python alternative for MATLAB users, and much of its syntax reflects that fact.
# The MATLAB-style tools are contained in the pyplot (``plt``) interface. See the example inthe code cell below.

# %%
plt.figure()  # create a plot figure

# create the first of two panels and set current axis
plt.subplot(2, 1, 1) # (rows, columns, panel number)
plt.plot(x, np.sin(x))

# create the second panel and set current axis
plt.subplot(2, 1, 2)
plt.plot(x, np.cos(x));

# %% [markdown]
# This interface is *stateful*: It keeps track of the "current" figure and axes, which are where all ``plt`` commands are applied.
#
# You can get a reference to these using the ``plt.gcf()`` (get current figure) and ``plt.gca()`` (get current axes) routines.
#
# While this stateful interface is fast and convenient for simple plots, it is easy to run into problems.
#
# For example, once the second panel is created, how can we go back and add something to the first? This interface does have a solution but it is not a easy solution.

# %% [markdown]
# #### Object-oriented interface of Matplotlib
#
# The object-oriented interface can nicely handle more complicated  plots, and for when you want more control over your figure.
#
# Rather than depending on some notion of an "active" figure or axes, in the object-oriented interface the plotting functions are *methods* of explicit ``Figure`` and ``Axes`` objects.
#
# To re-create the previous plot using this style of plotting, you might do the following:

# %%
#First create a grid of plots
# ax will be an array of two Axes objects
fig, ax = plt.subplots(2)

# Call plot() method on the appropriate object
ax[0].plot(x, np.sin(x))
ax[1].plot(x, np.cos(x))

# %% [markdown]
#  The difference is as small as switching ``plt.plot()`` to ``ax.plot()``.
#
#  Now we start exploring different types of plots in following sections.

# %% [markdown]
# ### Simple Line Plots
#
# Perhaps the simplest of all plots is the visualization of a single function ``y = f(x)``.
#
# Here we will take a first look at creating a simple plot of this type.

# %%
# Import all necesssary libraries
# %matplotlib inline  
import numpy as np
import matplotlib.pyplot as plt
#ploting style chosen is that of seaborn-whitegrid
plt.style.use('seaborn-whitegrid')

# %%
# creating objects of figure and axes.
fig = plt.figure()
ax = plt.axes()

# %% [markdown]
# In Matplotlib, the *figure* (an instance of the class ``plt.Figure``) can be thought of as a single container that contains all the objects representing axes, graphics, text, and labels.
#
# The *axes* (an instance of the class ``plt.Axes``) is what we see above: a bounding box with ticks and labels, which will eventually contain the plot elements that make up our visualization.
#
# Once we have created an axes, we can use the ``ax.plot`` function to plot some data.

# %%
# we will plot sine curve using ax.plot function
fig = plt.figure()
ax = plt.axes()
x = np.linspace(0, 10, 1000)
ax.plot(x, np.sin(x));

# %% [markdown]
# The word line in line plot refers to the function we want to plot. Multiple functions can be plot on same plot like shown below.

# %%
plt.plot(x, np.sin(x))   #shown in blue
plt.plot(x, np.sin(2*x)) #Shown in green 
plt.plot(x,(x**(1/2))/2) #Shown in red

# %% [markdown]
# ###Adjusting the Plot: Line Colors and Styles
#
# The first adjustment you might wish to make to a plot is to control the line colors and styles. The *plt.plot()* function takes additional arguments that can be used to specify these. To adjust the color, you can use the color keyword, which accepts a *string* argument representing virtually any imaginable color. The color can be specified in a variety of ways:

# %%
plt.plot(x, np.sin(x - 0), color='blue')        # specify color by name
plt.plot(x, np.sin(x - 1), color='g')           # short color code (rgbcmyk)
plt.plot(x, np.sin(x - 2), color='0.75')        # Grayscale between 0 and 1
plt.plot(x, np.sin(x - 3), color='#FFDD44')     # Hex code (RRGGBB from 00 to FF)
plt.plot(x, np.sin(x - 4), color=(1.0,0.2,0.3)) # RGB tuple, values 0 to 1
plt.plot(x, np.sin(x - 5), color='chartreuse'); # all HTML color names supported

# %%
plt.plot(x, x + 0, linestyle='solid')
plt.plot(x, x + 1, linestyle='dashed')
plt.plot(x, x + 2, linestyle='dashdot')
plt.plot(x, x + 3, linestyle='dotted');

# For short, you can use the following codes:
plt.plot(x, x + 4, linestyle='-')  # solid
plt.plot(x, x + 5, linestyle='--') # dashed
plt.plot(x, x + 6, linestyle='-.') # dashdot
plt.plot(x, x + 7, linestyle=':');  # dotted

# %% [markdown]
# ###Adjusting the Plot: Axes Limits
#
# Matplotlib does a decent job of choosing default axes limits for your plot, but sometimes it's nice to have finer control. The most basic way to adjust axis limits is to use the *plt.xlim()* and *plt.ylim()* methods:

# %%
plt.plot(x, np.sin(x))

plt.xlim(-1, 11)
plt.ylim(-1.5, 1.5);

# %%
# Reverse the Axis Limit
plt.plot(x, np.sin(x))

plt.xlim(10, 0)
plt.ylim(1.2, -1.2);

# %% [markdown]
# A useful related method is plt.axis() (note here the potential confusion between axes with an e, and axis with an i). The plt.axis() method allows you to set the x and y limits with a single call, by passing a list which specifies **[xmin, xmax, ymin, ymax] :**

# %%
plt.plot(x, np.sin(x))
plt.axis([-1, 11, -1.5, 1.5]);

# %% [markdown]
# ###Labeling Plots
#
# As the last piece of this section, we'll briefly look at the labeling of plots: titles, axis labels, and simple legends.
#
# Titles and axis labels are the simplest such labels—there are methods that can be used to quickly set them:

# %%
plt.plot(x, np.sin(x))
plt.title("A Sine Curve")
plt.xlabel("x")
plt.ylabel("sin(x)");

# %% [markdown]
# When multiple lines are being shown within a single axes, it can be useful to create a plot legend that labels each line type.
#
# Again, Matplotlib has a built-in way of quickly creating such a legend. It is done via the (you guessed it) **plt.legend()** method.
#
# Though there are several valid ways of using this, I find it easiest to specify the label of each line using the label keyword of the plot function:

# %%
plt.plot(x, np.sin(x), '-g', label='sin(x)')
plt.plot(x, np.cos(x), ':b', label='cos(x)')
plt.axis('equal')

plt.legend();

# %% [markdown]
# In the object-oriented interface to plotting, rather than calling these functions individually, it is often more convenient to use the ax.set() method to set all these properties at once:

# %%
ax = plt.axes()
ax.plot(x, np.sin(x))
ax.set(xlim=(0, 10), ylim=(-2, 2),
       xlabel='x', ylabel='sin(x)',
       title='A Simple Plot');

# %% [markdown]
# ###Simple Scatter Plots
# Another commonly used plot type is the simple scatter plot, a close cousin of the line plot. Instead of points being joined by line segments, here the points are represented individually with a dot, circle, or other shape.

# %%
rng = np.random.RandomState(0)
for marker in ['o', '.', ',', 'x', '+', 'v', '^', '<', '>', 's', 'd']:
    plt.plot(rng.rand(5), rng.rand(5), marker,
             label="marker='{0}'".format(marker))
plt.legend(numpoints=1)
plt.xlim(0, 1.8);

# %% [markdown]
# ###Scatter Plots with plt.scatter
#
# A second, more powerful method of creating scatter plots is the plt.scatter function, which can be used very similarly to the plt.plot function:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate the average of 25 consecutive elements from sorted_summer_temp and store them in objects x and y
sorted_summer_temp = np.array([29.07968109, 25.07129796, 22.46828854, 32.13927981, 28.14493701, 23.07872895, 31.73957399, 33.21031765, 28.62480429, 26.22914346])
x = np.array([np.mean(sorted_summer_temp[i:i+25]) for i in range(len(sorted_summer_temp)-25)])
y = np.array([np.mean(sorted_summer_temp[i:i+25]) for i in range(25, len(sorted_summer_temp))])

# Create a scatter plot of the values in x and y
plt.scatter(x, y, marker='o')
plt.title('Average of 25 Consecutive Elements from Sorted Summer Temperatures')
plt.xlabel('First 75 Values')
plt.ylabel('Last 75 Values')
plt.show()

# %%
# Consider this code for scatter plot 

rng = np.random.RandomState(0)
x = rng.randn(100)
y = rng.randn(100)
colors = rng.rand(100)
sizes = 1000 * rng.rand(100)

plt.scatter(x, y, c=colors, s=sizes, alpha=0.3,
            cmap='viridis')
plt.colorbar();  # show color scale

# %% [markdown]
# ##Question Answer Section
#
#
# 1. List any 2 **python APIs** that are used for Plotting Graphs.
#
# Ans. There are several Python APIs that can be used for plotting graphs. Here are two commonly used ones:
#
# 1. Matplotlib: Matplotlib is a widely used plotting library for Python. It provides a range of functions for creating different types of visualizations, including line plots, scatter plots, bar charts, and histograms.
#
# 2. Seaborn: Seaborn is a higher-level data visualization library based on Matplotlib. It provides an interface for creating more complex statistical graphics like heatmaps, joint plots, and factor plots, with minimal code.
#
# Other popular Python APIs for plotting graphs include Plotly, Bokeh, and ggplot.

# %% [markdown]
# 2. Name 2 important machnisms used for accesssing Matplotlib API.
#
# Ans. There are two important mechanisms for accessing the Matplotlib API:
#
# 1. Pyplot: Pyplot is a module in Matplotlib that provides a simple interface for creating a wide range of plots. It allows you to create and modify plots with simple commands like plt.plot() and plt.xlabel(), without having to worry about low-level details.
#
# 2. Object-oriented interface: Matplotlib also provides an object-oriented API for creating plots, which gives you more control over the layout and properties of your plots. With this interface, you create a Figure object that contains one or more Axes objects, which are used to create the actual plot. This approach allows you to customize every aspect of your plot and create more complex visualizations.
#
# Both of these mechanisms are useful and powerful, and the choice between them often comes down to personal preference and the specific needs of your project.

# %% [markdown]
# 3. Create a collection of 100 random normal numbers with parameter mean 30, sd 4 store it in object summer_temp
#
# Ans. To create a collection of 100 random normal numbers with mean 30 and standard deviation 4, you can use the numpy.random.normal() function from the NumPy library. Here's the code to create such a collection and store it in an object called summer_temp:

# %%
import numpy as np

# Create a collection of 100 random normal numbers with mean 30 and standard deviation 4
summer_temp = np.random.normal(30, 4, 100)

# Print the first 10 numbers in the collection
print(summer_temp[:10])
# Out:
# [29.07968109 25.07129796 22.46828854 32.13927981 28.14493701 23.07872895
#  31.73957399 33.21031765 28.62480429 26.22914346]

# %% [markdown]
# This code creates an array of 100 random numbers with a normal distribution, where the mean is 30 and the standard deviation is 4. The print() statement prints the first 10 numbers in the collection to the console. You can adjust the number of random numbers generated by changing the second argument (100) to the desired number.

# %% [markdown]
# 4. Sort above set and store in object sorted_summer_temp
#
# Ans. To store the array [29.07968109, 25.07129796, 22.46828854, 32.13927981, 28.14493701, 23.07872895, 31.73957399, 33.21031765, 28.62480429, 26.22914346] in an object called sorted_summer_temp, you can simply assign the array to the variable name sorted_summer_temp, like this:

# %%
import numpy as np

summer_temp = np.array([29.07968109, 25.07129796, 22.46828854, 32.13927981, 28.14493701, 23.07872895, 31.73957399, 33.21031765, 28.62480429, 26.22914346])

# %% [markdown]
# This code uses NumPy's array() function to create a NumPy array from the given list of values, and assigns it to the variable name sorted_summer_temp. Now, you can use this variable to perform operations on the temperature data, such as calculating the mean or plotting it on a graph.

# %% [markdown]
# 5. Store average of 25 consecutive elements  from sorted_summer_temp into object x and plot it as a *line plot*. What kind of information do u get about the data?
#
# Ans. To store the average of 25 consecutive elements from sorted_summer_temp into a new object called x, and plot it as a line plot, you can use the NumPy mean() function and Matplotlib's plot() function. Here's the code to do this:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate the average of 25 consecutive elements from sorted_summer_temp and store it in object x
x = np.array([np.mean(summer_temp[i:i+25]) for i in range(len(summer_temp)-25)])

# Plot the values of x as a line plot
plt.plot(x)
plt.title('Average of 25 Consecutive Elements from Sorted Summer Temperatures')
plt.xlabel('Index')
plt.ylabel('Average Temperature')
plt.show()

# %% [markdown]
# This code first uses a list comprehension to calculate the mean of each set of 25 consecutive elements from sorted_summer_temp, and stores the resulting array in a new object called x. Then, it plots the values in x as a line plot using plt.plot(), and adds a title and labels for the x and y axes using plt.title(), plt.xlabel(), and plt.ylabel(). Finally, it displays the plot using plt.show().
#
# By plotting the average temperatures of consecutive sets of 25 values, we can observe trends in the temperature data that might not be apparent from looking at individual values. The line plot can reveal patterns such as overall trends, periodic fluctuations, or sudden changes in temperature over time. It can also give us an idea of the overall variability of the temperature data. The specific information we get from the plot will depend on the nature of the temperature data and the specific range of values included in the plot.

# %% [markdown]
# 6. Repeat above step for summer_temp, store summary in object y and this time use *scatter plot* to plot values.  What kind of information do u get about the data?
#
# Ans. To store the average of 25 consecutive elements from sorted_summer_temp into a new object called y, and plot it as a scatter plot, you can use the NumPy mean() function and Matplotlib's scatter() function. Here's the code to do this:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate the average of 25 consecutive elements from sorted_summer_temp and store it in object y
y = np.array([np.mean(summer_temp[i:i+25]) for i in range(len(summer_temp)-25)])

# Plot the values of y as a scatter plot
plt.scatter(range(len(y)), y)
plt.title('Average of 25 Consecutive Elements from Sorted Summer Temperatures')
plt.xlabel('Index')
plt.ylabel('Average Temperature')
plt.show()

# %% [markdown]
# This code first uses a list comprehension to calculate the mean of each set of 25 consecutive elements from sorted_summer_temp, and stores the resulting array in a new object called y. Then, it plots the values in y as a scatter plot using plt.scatter(), and adds a title and labels for the x and y axes using plt.title(), plt.xlabel(), and plt.ylabel(). Finally, it displays the plot using plt.show().
#
# By plotting the average temperatures of consecutive sets of 25 values as a scatter plot, we can observe the distribution and spread of the temperature data. The scatter plot can reveal patterns such as clusters of similar temperature values, outliers, or gaps in the data. It can also give us an idea of the overall variability of the temperature data, as well as any trends or changes over time. The specific information we get from the plot will depend on the nature of the temperature data and the specific range of values included in the plot.

# %% [markdown]
# 7. plot *summer_temp* and *y* together in same line plot.
#
# Ans. To store the average of 25 consecutive elements from sorted_summer_temp into two new objects called x and y, and plot them as a line plot, you can use the NumPy mean() function and Matplotlib's plot() function. Here's the code to do this:

# %%
import numpy as np
import matplotlib.pyplot as plt

# Calculate the average of 25 consecutive elements from sorted_summer_temp and store them in objects x and y
x = np.array([np.mean(summer_temp[i:i+25]) for i in range(len(summer_temp)-25)])
y = np.array([np.mean(summer_temp[i:i+25]) for i in range(25, len(summer_temp))])

# Plot the values of x and y as a line plot
plt.plot(x)
plt.plot(y)
plt.title('Average of 25 Consecutive Elements from Sorted Summer Temperatures')
plt.xlabel('Index')
plt.ylabel('Average Temperature')
plt.legend(['First 75 values', 'Last 75 values'])
plt.show()

# %% [markdown]
# This code first uses two list comprehensions to calculate the mean of each set of 25 consecutive elements from sorted_summer_temp, and stores the resulting arrays in two new objects called x and y. Then, it plots the values in x and y as a line plot using plt.plot(), and adds a title and labels for the x and y axes using plt.title(), plt.xlabel(), and plt.ylabel(). Finally, it displays the plot using plt.show(), and adds a legend to differentiate between the first and last 75 values.
#
# By plotting the average temperatures of consecutive sets of 25 values as a line plot, we can observe trends in the temperature data over time. The line plot can reveal patterns such as overall trends, periodic fluctuations, or sudden changes in temperature. It can also give us an idea of the overall variability of the temperature data, and how it changes over time. By plotting both the first and last 75 values on the same plot, we can compare the patterns and trends in the temperature data across different time periods. The specific information we get from the plot will depend on the nature of the temperature data and the specific range of values included in the plot.

# %% [markdown]
# ## Conclusion
# Thus we have learned abou basics of ploting using *matplotlib*.
